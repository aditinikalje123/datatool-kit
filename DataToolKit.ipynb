# %% [markdown]
# # THEORY QUESTIONS
#
# 1) What is NumPy, and why is it widely used in Python
# Ans:- numpy is a library in python, use to solve numerical array problems and it is calles numerical pythonIt provides support for multi-dimensional arrays, along with a collection of mathematical functions to operate on these arrays.
#
# 2) How does broadcasting work in NumPy
# Ans:-allows operations on arrays of different shapes by expanding the smaller array to match the shape of the larger one, without physically altering the arrays
#
# 3)What is a Pandas DataFrame
# Ans:-A Pandas DataFrame is a two-dimensional, size-mutable, and potentially heterogeneous tabular data structure with labeled axes (rows and columns). It is a fundamental data structure in the Pandas library, which is a popular Python library for data manipulation and analysis.
#
# 4) Explain the use of the groupby() method in Pandas
# Ans:-The groupby() method in Pandas is a powerful tool used to group rows in a DataFrame based on the values of one or more columns. It facilitates the application of functions to each group independently, enabling efficient data analysis and transformation.
#
# 5)Why is Seaborn preferred for statistical visualizations
# Ans:-Seaborn is more than just a tool for creating attractive plots—it's a gateway to understanding data. Its ability to simplify statistical plotting, integrate with pandas, and support a wide range of customization options makes it an essential library for anyone involved in data analysis and visualization.
#
# 6)A What are the differences between NumPy arrays and Python lists
# Ans:-NumPy arrays:
# Designed for numerical data and require all elements to be of the same data type (homogeneous). This uniformity allows for optimized storage and mathematical operations.
# Python lists:
# Can store elements of different data types (heterogeneous), providing flexibility but sacrificing performance for numerical computations.
#
# 7)What is a heatmap, and when should it be used
# Ans:-A heatmap is a visual representation of data using color variations to depict the frequency or intensity of values across a two-dimensional space
#
# 8)A What does the term “vectorized operation” mean in NumPy
# Ans:-Vectorized operations, on the other hand, take advantage of low-level optimizations implemented in libraries like NumPy (which pandas is built on). These operations apply a function to an entire array (or DataFrame/Series) at once, leveraging highly efficient C and Fortran code under the hood
#
# 9)How does Matplotlib differ from Plotly
# Ans:-Matplotlib: Is often preferred for academic or highly customized plots because you can fine-tune just about any aspect of the figure—fonts, margins, axis scales, etc. Plotly: While still highly customizable, Plotly's real strength lies in interactivity and web-based visuals.
#
# 10)What is the significance of hierarchical indexing in Pandas
# Ans:-Hierarchical indexing, also known as MultiIndexing, is a powerful feature in Pandas that allows you to have multiple levels of indexing on an axis (row or column). It enables you to represent higher-dimensional data within lower-dimensional data structures like Series (1D) and DataFrames (2D).
#
# 11)What is the role of Seaborn’s pairplot() function
# Ans:-The pairplot() function in Seaborn is a high-level interface for creating a matrix of scatter plots, also known as a scatterplot matrix. It is a useful tool for exploratory data analysis (EDA).
#
# 12) What is the purpose of the describe() function in Pandas
# Ans:-The describe() function in Pandas is used to generate descriptive statistics of a DataFrame or Series. It provides a quick summary of key statistical metrics, which can be useful for understanding the distribution and characteristics of your data.
#
# 13)Why is handling missing data important in Pandas
# Ans:-Data Integrity,Algorithm Compatibility,Data Loss Mitigation
#
# 14) What are the benefits of using Plotly for data visualization
# Ans:-build interactive apps, question your data to uncover trends, and generate boilerplate code.
#
# 15)How does NumPy handle multidimensional arrays
# Ans:-NumPy handles multidimensional arrays, also known as ndarrays, by storing them as contiguous blocks of memory. This allows for efficient access and manipulation of array elements.
#
# 16)What is the role of Bokeh in data visualization
# Ans:-Bokeh is a Python library that plays a crucial role in data visualization by enabling the creation of interactive and dynamic plots and dashboards for web browsers
#
# 17)Explain the difference between apply() and map() in Pandas
# Ans:-map():- transform or replace each value in a Series based on a mapping correspondence. The mapping can be a function, a dictionary, or another Series.
# apply():-To apply a function along an axis of a DataFrame or on the values of a Series. The function can be more complex than a simple mapping.
#
# 18)What are some advanced features of NumPy
# Ans:-These include broadcasting for efficient array operations, advanced indexing and slicing for flexible data selection, and structured arrays for handling complex data structures.
#
# 19)How does Pandas simplify time series analysis
# Ans:-using dates and times to intuitively organize and access our data. With time-based indexing, we can use date/time formatted strings to select data in our DataFrame with the loc accessor.
#
# 20)A What is the role of a pivot table in Pandas
# Ans:-The pivot() function is an incredibly useful tool for transforming and summarizing data. It allows you to restructure a DataFrame by turning rows into columns and columns into rows based on a specified index column, a specified columns column, and a specified values column.
#
# 21)Why is NumPy’s array slicing faster than Python’s list slicing
# Ans:-Contiguous Memory,Homogeneous Data Types,  Optimized C Implementation,
# Vectorization.
#
# 22)What are some common use cases for Seaborn
# Ans:-Histogram.
# Box Plot.
# Violin Plot.
# Heatmap.
# Pairplot

# %% [markdown]
# #PRACTICAL QUESTOINS
# 1)How do you create a 2D NumPy array and calculate the sum of each row
# Ans:-

# %%
import numpy as np

# Importing the NumPy library with an alias 'np'
import numpy as np

# Creating a NumPy array 'x' with a 2x2 shape
x = np.array([[0, 1], [2, 3]])

# Printing a message indicating the original array 'x'
print("Original array:")
print(x)

# Calculating and printing the sum of all elements in the array 'x' using np.sum()
print("Sum of all elements:")
print(np.sum(x))

# Calculating and printing the sum of each column in the array 'x' using np.sum() with axis=0
print("Sum of each column:")
print(np.sum(x, axis=0))

# Calculating and printing the sum of each row in the array 'x' using np.sum() with axis=1
print("Sum of each row:")
print(np.sum(x, axis=1))
# Out:
# Original array:
# [[0 1]
#  [2 3]]
# Sum of all elements:
# 6
# Sum of each column:
# [2 4]
# Sum of each row:
# [1 5]

# %% [markdown]
# 2)Write a Pandas script to find the mean of a specific column in a DataFrame

# %%
import pandas as pd

def calculate_column_mean(df, column_name):
    """
    Calculates the mean of a specified column in a Pandas DataFrame.

    Args:
        df (pd.DataFrame): The input DataFrame.
        column_name (str): The name of the column to calculate the mean for.

    Returns:
        float: The mean of the specified column.
    """
    if column_name not in df.columns:
        raise ValueError(f"Column '{column_name}' not found in DataFrame.")

    return df[column_name].mean()

if __name__ == '__main__':
    # Sample DataFrame
    data = {'col1': [1, 2, 3, 4, 5],
            'col2': [6, 7, 8, 9, 10],
            'col3': [11, 12, 13, 14, 15]}
    df = pd.DataFrame(data)

    # Calculate the mean of 'col2'
    try:
        mean_value = calculate_column_mean(df, 'col2')
        print(f"The mean of 'col2' is: {mean_value}")
    except ValueError as e:
        print(e)

    # Example of a column not found
    try:
        mean_value = calculate_column_mean(df, 'col4')
        print(f"The mean of 'col4' is: {mean_value}")
    except ValueError as e:
        print(e)
# Out:
# The mean of 'col2' is: 8.0
# Column 'col4' not found in DataFrame.

# %% [markdown]
# 3)Create a scatter plot using Matplotlib

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 4, 1, 3, 5]

plt.scatter(x, y, color='red', marker='o', s=100)
plt.xlabel("X-axis label")
plt.ylabel("Y-axis label")
plt.title("My Scatter Plot")
plt.show()

# %% [markdown]
# 4) How do you calculate the correlation matrix using Seaborn and visualize it with a heatmap

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming your data is in a Pandas DataFrame called 'df'

# Calculate the correlation matrix
correlation_matrix = df.corr()

# Create the heatmap
plt.figure(figsize=(10, 8))  # Adjust figure size as needed
sns.heatmap(correlation_matrix, cmap="coolwarm", annot=True, fmt=".2f")
plt.title("Correlation Matrix Heatmap")
plt.show()

# %% [markdown]
# 5)Generate a bar plot using Plotly

# %%
import plotly.express as px

# Sample data
categories = ['A', 'B', 'C', 'D']
values = [25, 18, 32, 20]

# Create the bar chart
fig = px.bar(x=categories, y=values, title='Simple Bar Chart')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 6)A Create a DataFrame and add a new column based on an existing column

# %%
import numpy as np
import pandas as pd

df = pd.DataFrame({"A": [1, 2, 3, 4],
                   "B": [5, 6, 7, 8]})

df
# Out:
#    A  B
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8

# %% [markdown]
# 7)Write a program to perform element-wise multiplication of two NumPy arrays

# %%
import numpy as np

def elementwise_multiply(array1, array2):
    """
    Performs element-wise multiplication of two NumPy arrays.

    Args:
        array1: The first NumPy array.
        array2: The second NumPy array.

    Returns:
        A new NumPy array containing the element-wise product of the two input arrays.
        Returns None if the arrays have different shapes.
    """
    if array1.shape != array2.shape:
        print("Error: Arrays must have the same shape for element-wise multiplication.")
        return None

    return np.multiply(array1, array2)

if __name__ == '__main__':
    # Example Usage
    array1 = np.array([[1, 2], [3, 4]])
    array2 = np.array([[5, 6], [7, 8]])

    result = elementwise_multiply(array1, array2)

    if result is not None:
        print("Array 1:")
        print(array1)
        print("\nArray 2:")
        print(array2)
        print("\nElement-wise Multiplication Result:")
        print(result)

# %% [markdown]
# 8)Create a line plot with multiple lines using Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data preparation
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.sin(x) * np.cos(x)

# Plotting
plt.plot(x, y1, label='sin(x)', color='blue', linestyle='-')
plt.plot(x, y2, label='cos(x)', color='red', linestyle='--')
plt.plot(x, y3, label='sin(x)*cos(x)', color='green', linestyle=':')

# Labels and title
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Multiple Line Plot')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# 9)Generate a Pandas DataFrame and filter rows where a column value is greater than a threshold

# %%
import pandas as pd

# Create a sample DataFrame
data = {'col1': [1, 2, 3, 4, 5],
        'col2': [6, 7, 8, 9, 10]}
df = pd.DataFrame(data)

# Define the threshold
threshold = 3

# Filter rows where 'col1' is greater than the threshold
filtered_df = df[df['col1'] > threshold]

# Print the filtered DataFrame
print(filtered_df)
# Out:
#    col1  col2
# 3     4     9
# 4     5    10

# %% [markdown]
# 10)Create a histogram using Seaborn to visualize a distribution

# %%
import pandas as pd
import numpy as np

# Example data:
data = np.random.randn(1000)
df = pd.DataFrame({'values': data})
sns.histplot(data=df, x='values')
plt.show()
sns.histplot(data=df, x='values', bins=30, kde=True, color='skyblue', edgecolor='black', stat='density')
plt.xlabel('Values')
plt.ylabel('Density')
plt.title('Customized Histogram')
plt.show()

mean_value = df['values'].mean()
median_value = df['values'].median()

sns.histplot(data=df, x='values')
plt.axvline(mean_value, color='red', label='Mean', linewidth=2)
plt.axvline(median_value, color='green', label='Median', linewidth=2)
plt.legend()
plt.show()

# %% [markdown]
# 11)Perform matrix multiplication using NumP

# %%
   import numpy as np

   # Create two matrices
   matrix1 = np.array([[1, 3], [5, 7]])
   matrix2 = np.array([[2, 6], [4, 8]])

   # Perform matrix multiplication using dot product
   result = np.dot(matrix1, matrix2)
   print(result)
# Out:
# [[14 30]
#  [38 86]]

# %% [markdown]
# 12)Use Pandas to load a CSV file and display its first 5 rows

# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('services.csv')

# Display the first 5 rows
print(df.head())
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male
# 3      4  A31Bee3c201ef58    Yesenia  Martinez    Male
# 4      5  1bA7A3dc874da3c       Lori      Todd    Male
#
#                         Email                   Phone Date of birth  \
# 0        elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1       bethany14@example.com       214.112.6044x4913    1910-03-24
# 2       bthompson@example.com            277.609.7938    1992-07-02
# 3   kaitlinkaiser@example.com            584.094.6111    2017-08-03
# 4  buchananmanuel@example.net       689-207-3558x7233    1938-12-01
#
#             Job Title
# 0     Games developer
# 1      Phytotherapist
# 2           Homeopath
# 3   Market researcher
# 4  Veterinary surgeon

# %% [markdown]
# 13)Create a 3D scatter plot using Plotly.

# %%
   import plotly.express as px
   import numpy as np

   # Sample data
   np.random.seed(42)
   x = np.random.rand(100)
   y = np.random.rand(100)
   z = np.random.rand(100)
   c = np.random.rand(100) # Color data

   # Create the scatter plot
   fig = px.scatter_3d(x=x, y=y, z=z, color=c)

   # Show the plot
   fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
